# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from radmc3dPy import *
im=image.readImage()
image.plotImage(im,vmax=3e-3,au=True,cmap=cm.gist_heat)
# Out:
# astropy.io.fits cannot be imported trying pyfits
# pyfits cannot be imported. Either of these modules is needed to write RADMC-3D images to FITS format. The rest of radmc3dPy can be used but fits output is now disabled.
# Traceback (most recent call last):
#   File "/Users/emafikre/Library/Python/3.10/lib/python/site-packages/radmc3dPy/image.py", line 29, in <module>
#     from astropy.io import fits as pf
# ModuleNotFoundError: No module named 'astropy'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/emafikre/Library/Python/3.10/lib/python/site-packages/radmc3dPy/image.py", line 33, in <module>
#     import pyfits as pf
# ModuleNotFoundError: No module named 'pyfits'
#
# Reading image.out
# {'implot': <matplotlib.image.AxesImage at 0x12acb2230>,
#  'cbar': <matplotlib.colorbar.Colorbar at 0x12ad52a10>}

# %%
import os
import sys
home = os.environ["HOME"]
sys.path.append(home+'/bin/python')

# %%
import matplotlib.pyplot as plt
from radmc3d_tools.simpleread import *
import radmc3d_tools.natconst as nc
tm = read_dusttemp()
plt.figure()
plt.plot(tm.grid.x/nc.au,tm.dusttemp[:,16,16])
plt.xlabel('x [au]')
plt.ylabel('T [K]')
im = read_image()
plt.figure()
plt.imshow(im.image[:,:,0],vmax=3e-14)
plt.show()
# Out:
# Reading amr_grid.inp
# Reading dust_temperature.dat
# Reading image.out
